# %%
# !py -m pip install openai
# !py -m pip install numpy
# !py -m pip install pandas

# %%
import csv
import openai
import time
import pandas as pd
import numpy as np
import os

# %%
openai.api_type = "azure"
openai.api_base = "https://training-openai.openai.azure.com/"
openai.api_version = "2023-05-15"
openai.api_key = "e47fa4d8098f420e84365337e5794f2f"

# %%
import openai

openai.api_type = "azure"
openai.api_base = "https://fusion-chatbot-demo.openai.azure.com/"
openai.api_version = "2023-03-15-preview"
openai.api_key = "f07d23e10600494f8235496bbf5054b9"

# %%
openai.api_key = os.getenv("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")

# %%
QandA_generated_part_1 = '''

Please generate a question and answer (Q&A) between the insured and the insurer where the question from the insured has to be in a '''

QandA_generated_part_2 = ''' tone for 5 Q&A
Please generate a result like this

Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 1:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 1:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 2:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 2:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 3:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 3:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 4:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 4:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 5:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 5:CCCCCCCCCCCCCCCCCCCCCCCCCC

Please generate in Thai's Language
Please do it in a form that can be record to csv files
the number range of plan mean this plan is suitable for insurer Age n-m
Please remain the input topic be the same.
'''

QandA_informal_generated = '''

Please generate a question and answer (Q&A) between the insured and the insurer where the question from the insured has to be messy, funny or 
inappropriate but the answer from the insurer is serious and appropriate base on this insurance plan topic for 5 Q&A
Please generate a result like this

Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 1:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 1:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 2:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 2:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 3:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 3:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 4:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 4:CCCCCCCCCCCCCCCCCCCCCCCCCC
Age:Y;Plan:XXXXXXXXXXX;Topic :AAAAAAAAAAAAAAAAAAAAAAAAAAAA;Question 5:BBBBBBBBBBBBBBBBBBBBBBBBBB;Answer 5:CCCCCCCCCCCCCCCCCCCCCCCCCC

Please generate in Thai's Language
Please do it in a form that can be record to csv files
the number range of plan mean this plan is suitable for insurer Age n-m
Please remain the input topic be the same.
'''

# %%
df2 = pd.read_csv("topic_extracted_kai.csv",header=None)

df3 = pd.read_csv("topic_extracted_kai_part1.csv",header=None)

df4 = pd.read_csv("topic_extracted_kai_part2.csv",header=None)

#Topic First half
topic1 = np.squeeze(df3[2].values)
topic_list1 = [topic1 for topic1 in topic1]
plan1 = np.squeeze(df3[1].values)
plan_list1 = [plan1 for plan1 in plan1]
age1 = np.squeeze(df3[0].values)
age_list1 = [age1 for age1 in age1]
print(plan_list1,topic_list1,age_list1)

#Topic Second half
topic2 = np.squeeze(df4[2].values)
topic_list2 = [topic2 for topic2 in topic2]
plan2 = np.squeeze(df4[1].values)
plan_list2 = [plan2 for plan2 in plan2]
age2 = np.squeeze(df4[0].values)
age_list2 = [age2 for age2 in age2]
print(plan_list2,topic_list2,age_list2)

import numpy as np
topic = np.squeeze(df2[2].values)
topic_list = [topic for topic in topic]
plan = np.squeeze(df2[1].values)
plan_list = [plan for plan in plan]
age = np.squeeze(df2[0].values)
age_list = [age for age in age]
print(plan_list,topic_list,age_list)
# Out:
# [' แผน:สมาย คิดส์', ' แผน:สมาย คิดส์', ' แผน:สมาย คิดส์', ' แผน:ก้าวแรก', ' แผน:ก้าวแรก', ' แผน:ก้าวแรก', ' แผน:ก้าวแรก', ' แผน:ก้าวแรก', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:สมาย คิดส์', ' แผน:สมาย คิดส์', ' แผน:สมาย คิดส์', ' แผน:สมาย คิดส์', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. คลาสสิค ชีลด์', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. บียอนด์ สมาร์ตโพรเทกชั่น', ' แผน:พี.เอ. รีฟันด์', ' แผน:พี.เอ. รีฟันด์', ' แผน:พี.เอ. รีฟันด์', ' แผน:พี.เอ. รีฟันด์', ' แผน:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี', ' แผน:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี', ' แผน:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ
# ...

# %% [markdown]
# # Concerned

# %%
Concerned_list1=[]
for age_lists,plan_lists,topic_lists in zip(age_list1,plan_list1,topic_list1):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated__part_1+"Concerned"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Concerned_list1.append(answer)
    
    time.sleep(5)
    
    print(answer)
# Out:
# Age:1-5;Plan:สมาย คิดส์;Topic :ค่าชดเชยรายวัน กรณีเข้าพักรักษาตัวในโรงพยาบาลสูงสุดวันละ 3,000 บาท;Question 1:ค่าชดเชยรายวัน 3,000 บาท นั้นเพียงพอสำหรับค่าใช้จ่ายในการรักษาตัวหรือไม่คะ?;Answer 1:ค่าชดเชยรายวัน 3,000 บาท นั้นออกแบบมาเพื่อช่วยเสริมค่าใช้จ่ายในการรักษาตัว แต่อาจไม่ครอบคลุมค่าใช้จ่ายทั้งหมด ขึ้นอยู่กับความรุนแรงของโรคและการรักษา
# Age:1-5;Plan:สมาย คิดส์;Topic :ค่าชดเชยรายวัน กรณีเข้าพักรักษาตัวในโรงพยาบาลสูงสุดวันละ 3,000 บาท;Question 2:หากเด็กของฉันต้องเข้าพักในโรงพยาบาลนานกว่า 1 วัน ฉันจะได้รับค่าชดเชยเต็มจำนวนหรือไม่คะ?;Answer 2:ใช่ค่ะ คุณจะได้รับค่าชดเชยรายวันสำหรับทุกวันที่เด็กของคุณเข้าพักในโรงพยาบาล ตามวันที่ระบุในกรมธรรม์ ไม่เกิน 3,000 บาทต่อวัน
# Age:1-5;Plan:สมาย คิดส์;Topic :ค่าชดเชยรายวัน กรณีเข้าพักรักษาตัวในโรงพยาบาลสูงสุดวันละ 3,000 บาท;Question 3:ถ้าค่าใช้จ่ายในการรักษาตัวเกิน 3,000 บาทต่อวัน ฉันต้องจ่ายเงินเพิ่มเองหรือไม่คะ?;Answer 3:ใช่ค่ะ หากค่าใช้จ่ายในการรักษาตัวเกิน 3,000 บาทต่อวัน คุณจะต้องจ่ายเงินเพิ่มเองสำหรับส่วนที่เกิน
# ...

# %%
# Clean the text by removing leading/trailing spaces and splitting into separate entries

extracted_concerned1 = []

for entry in Concerned_list1:
    parts = entry.split("\n")
    for each_parts in parts:
        each_part = each_parts.split(";")
        extracted_concerned1.append(each_parts)
        #age = each_part[0].split(":")[1]
        #plan = each_part[1].split(":")[1]
        #topic = each_part[2].split(":")[1]
        #question = each_part[3].split(":")[1]
        #answer = each_part[4].split(":")[1]        
        #extracted_data.append([age,plan,topic,question,answer])
        #age = each_part[0].split(":")[1]

def write_to_csv(data):
    with open("concerned_gen_1.csv", mode='a', newline='',encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(data)
        
write_to_csv(extracted_concerned1)

# %%
Concerned_list2=[]
for age_lists,plan_lists,topic_lists in zip(age_list2,plan_list2,topic_list2):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated__part_1+"Concerned"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Concerned_list2.append(answer)
    
    time.sleep(10)
    
    print(answer)
# Out:
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 1:ฉันจะได้รับเงินคืนทุกปีจริงๆ หรือไม่?;Answer 1:ใช่ค่ะ ท่านจะได้รับเงินคืนทุกปี ปีละ 1% ตามที่ระบุในแผนประกันภัยค่ะ
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 2:เมื่อครบกำหนดสัญญาฉันจะได้รับเงินคืนเท่าไหร่?;Answer 2:เมื่อครบกำหนดสัญญา ท่านจะได้รับเงินคืน 110% ค่ะ
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 3:เบี้ยประกันภัยจะเปลี่ยนแปลงไหม?;Answer 3:ไม่ค่ะ เบี้ยประกันภัยจะคงที่ตลอดสัญญาค่ะ
# ...

# %%
Concerned_list2
# Out:
# ['Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 1:ฉันจะได้รับเงินคืนทุกปีจริงๆ หรือไม่?;Answer 1:ใช่ค่ะ ท่านจะได้รับเงินคืนทุกปี ปีละ 1% ตามที่ระบุในแผนประกันภัยค่ะ\nAge:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 2:เมื่อครบกำหนดสัญญาฉันจะได้รับเงินคืนเท่าไหร่?;Answer 2:เมื่อครบกำหนดสัญญา ท่านจะได้รับเงินคืน 110% ค่ะ\nAge:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 3:เบี้ยประกันภัยจะเปลี่ยนแปลงไหม?;Answer 3:ไม่ค่ะ เบี้ยประกันภัยจะคงที่ตลอดสัญญาค่ะ\nAge:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 4:ถ้าฉั
# ...

# %%
# Clean the text by removing leading/trailing spaces and splitting into separate entries

extracted_concerned2 = []

for entry in Concerned_list2:
    parts = entry.split("\n")
    for each_parts in parts:
        each_part = each_parts.split(";")
        age = each_part[0].split(":")[1]
        plan = each_part[1].split(":")[1]
        topic = each_part[2].split(":")[1]
        question = each_part[3].split(":")[1]
        answer = each_part[4].split(":")[1]        
        extracted_concerned2.append([age,plan,topic,question,answer])
def write_to_csv(data):
    with open("concerned_gen_2.csv", mode='a', newline='',encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(data)
        
write_to_csv(extracted_concerned2)

# %%
extracted_concerned2
# Out:
# [['36-50',
#   'ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี',
#   'รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา',
#   'ฉันจะได้รับเงินคืนทุกปีจริงๆ หรือไม่?',
#   'ใช่ค่ะ ท่านจะได้รับเงินคืนทุกปี ปีละ 1% ตามที่ระบุในแผนประกันภัยค่ะ'],
#  ['36-50',
#   'ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี',
#   'รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา',
#   'เมื่อครบกำหนดสัญญาฉันจะได้รับเงินคืนเท่าไหร่?',
#   'เมื่อครบกำหนดสัญญา ท่านจะได้รับเงินคืน 110% ค่ะ'],
#  ['36-50',
#   'ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี',
#   'รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา',
#   'เบี้ยประกันภัยจะเปลี่ยนแปลงไหม?',
#   'ไม่ค่ะ เบี้ยประกันภัยจะคงที่ตลอดสัญญาค่ะ'],
#  ['36-50',
#   'ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี',
#   'รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา',
# ...

# %% [markdown]
# # Anxious

# %%
Anxious_list1=[]
for age_lists,plan_lists,topic_lists in zip(age_list1,plan_list1,topic_list1):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated__part_1+"Anxious"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=3000,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Anxious_list1.append(answer)
    
    time.sleep(20)
    
    print(answer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 Anxious_list1=[]
#       2 for age_lists,plan_lists,topic_lists in zip(age_list1,plan_list1,topic_list1):
# ----> 3     response = openai.ChatCompletion.create(
#       4         engine="gpt-4",
#       5         messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
#       6                     {"role":"user","content":QandA_generated__part_1+"Anxious"+QandA_generated_part_2}],
#       7         temperature=0.1,
#       8         max_tokens=3000,
#       9         top_p=0.1,
#      10         frequency_penalty=0,
#      11         presence_penalty=0,
#      12         stop=None
#      13     )
#      15     answer = response['choices'][0]['message']['content']
#      16     Anxious_list1.append(answer)
#
# ...

# %%
# Clean the text by removing leading/trailing spaces and splitting into separate entries

extracted_anxious1 = []

for entry in Anxious_list1:
    parts = entry.split("\n")
    for each_parts in parts:
        each_part = each_parts.split(";")
        age = each_part[0].split(":")[1]
        plan = each_part[1].split(":")[1]
        topic = each_part[2].split(":")[1]
        question = each_part[3].split(":")[1]
        answer = each_part[4].split(":")[1]        
        extracted_anxious1.append([age,plan,topic,question,answer])
def write_to_csv(data):
    with open("anxious_gen_1.csv", mode='a', newline='',encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(data)
        
write_to_csv(extracted_anxious1)

# %%
Anxious_list2=[]
for age_lists,plan_lists,topic_lists in zip(age_list2,plan_list2,topic_list2):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated__part_1+"Anxious"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=3000,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Anxious_list2.append(answer)
    
    time.sleep(10)
    
    print(answer)
# Out:
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 1:ฉันจะได้รับเงินคืนทุกปีจริงๆ หรือไม่?;Answer 1:ใช่ค่ะ ท่านจะได้รับเงินคืนทุกปี ปีละ 1% ตามที่ระบุในแผนประกันภัยค่ะ
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 2:เมื่อครบกำหนดสัญญาฉันจะได้รับเงินคืนเท่าไหร่?;Answer 2:เมื่อครบกำหนดสัญญา ท่านจะได้รับเงินคืน 110% ค่ะ
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic :รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 3:เบี้ยประกันภัยของฉันจะเพิ่มขึ้นหรือไม่?;Answer 3:ไม่ค่ะ เบี้ยประกันภัยของท่านจะคงที่ตลอดสัญญาค่ะ
# ...

# %%
# Clean the text by removing leading/trailing spaces and splitting into separate entries

extracted_anxious2 = []

for entry in Anxious_list2:
    parts = entry.split("\n")
    for each_parts in parts:
        each_part = each_parts.split(";")
        age = each_part[0].split(":")[1]
        plan = each_part[1].split(":")[1]
        topic = each_part[2].split(":")[1]
        question = each_part[3].split(":")[1]
        answer = each_part[4].split(":")[1]        
        extracted_anxious2.append([age,plan,topic,question,answer])
def write_to_csv(data):
    with open("anxious_gen_2.csv", mode='a', newline='',encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(data)
        
write_to_csv(extracted_anxious2)

# %%
Anxious_list2 = []

for age_lists, plan_lists, topic_lists in zip(age_list2, plan_list2, topic_list2):
    retry = True
    
    while retry:
        try:
            response = openai.ChatCompletion.create(
                engine="gpt-4",
                messages=[
                    {"role": "system", "content": 'Age:' + age_lists + 'Plan:' + plan_lists + 'Topic:' + topic_lists},
                    {"role": "user", "content": QandA_generated__part_1 + "Anxious" + QandA_generated_part_2}
                ],
                temperature=0.1,
                max_tokens=3000,
                top_p=0.1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=None
            )

            answer = response['choices'][0]['message']['content']
            Anxious_list2.append(answer)

            print(answer)
            
            # If the request succeeds, set retry to False to move to the next iteration
            retry = False

        except openai.error.ServiceUnavailableError:
            # Handle the error and retry the request
            print("Encountered ServiceUnavailableError. Retrying the request.")
            time.sleep(1)  # Wait for 1 second before retrying

        except openai.error.OpenAIError as e:
            # Handle other OpenAI errors that are not retryable
            print("An OpenAIError occurred:", str(e))
            break

        except Exception as e:
            # Handle other exceptions or errors that are not retryable
            print("An error occurred:", str(e))
            break

    time.sleep(10)
# Out:
# Encountered ServiceUnavailableError. Retrying the request.
# Encountered ServiceUnavailableError. Retrying the request.
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic:รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 1:ฉันจะได้รับเงินคืนทุกปีใช่ไหม ถ้าไม่ได้รับฉันควรทำอย่างไร?;Answer 1:ใช่ค่ะ คุณจะได้รับเงินคืนทุกปี ปีละ 1% หากไม่ได้รับกรุณาติดต่อเจ้าหน้าที่ของเราเพื่อตรวจสอบสถานะการชำระเบี้ยประกันค่ะ
# Age:36-50;Plan:ออมยาวคุ้มทวีคูณชำระเบี้ยสั้น 10 ปี คุ้มครองยาวถึงอายุ 85 ปี;Topic:รับเงินคืนทุกปี ปีละ 1%(1)(2) ครบกำหนดสัญญารับ 110%(1)(3) เบี้ยคงที่ตลอดสัญญา;Question 2:เมื่อครบกำหนดสัญญา 10 ปี ฉันจะได้รับเงินคืนเท่าไหร่?;Answer 2:เมื่อครบกำหนดสัญญา 10 ปี คุณจะได้รับเงินคืน 110% ของเบี้ยประกันที่คุณชำระค่ะ
# ...

# %% [markdown]
# # Frustrated

# %%
import os
import openai


openai.api_key = os.getenv("")
response = openai.ChatCompletion.create(
  model="gpt-4",
  messages=[
    {
      "role": "user",
      "content": ""
    }
  ],
  temperature=0.1,
  max_tokens=6000,
  top_p=0.1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
Frustrated_list = []

for age_lists, plan_lists, topic_lists in zip(age_list, plan_list, topic_list):
    retry = True
    
    while retry:
        try:
            response = openai.ChatCompletion.create(
                engine="gpt-4",
                messages=[
                    {"role": "system", "content": 'Age:' + age_lists + 'Plan:' + plan_lists + 'Topic:' + topic_lists},
                    {"role": "user", "content": QandA_generated_part_1 + "Frustrated" + QandA_generated_part_2}
                ],
                temperature=0.1,
                max_tokens=5000,
                top_p=0.1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=None
            )

            answer = response['choices'][0]['message']['content']
            Frustrated_list.append(answer)

            print(answer)
            
            # If the request succeeds, set retry to False to move to the next iteration
            retry = False

        except openai.error.ServiceUnavailableError:
            # Handle the error and retry the request
            print("Encountered ServiceUnavailableError. Retrying the request.")
            time.sleep(1)  # Wait for 1 second before retrying

        except openai.error.OpenAIError as e:
            # Handle other OpenAI errors that are not retryable
            print("An OpenAIError occurred:", str(e))
            break

        except Exception as e:
            # Handle other exceptions or errors that are not retryable
            print("An error occurred:", str(e))
            break

    time.sleep(10)
# Out:
# An OpenAIError occurred: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://platform.openai.com/account/api-keys for details.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 45
#      42         print("An error occurred:", str(e))
#      43         break
# ---> 45 time.sleep(10)
#
# KeyboardInterrupt:

# %%
Inquisitive_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Inquisitive"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Inquisitive_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
Determined_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Determined"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Determined_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
Cautious_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Cautious"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Cautious_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
Engaged_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Engaged"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Engaged_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
Reassuring_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Reassuring"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Reassuring_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
Open-minded_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_generated_part_1+"Open-minded"+QandA_generated_part_2}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    Open-minded_list.append(answer)
    
    time.sleep(10)
    
    print(answer)

# %%
informal_list=[]
for age_lists,plan_lists,topic_lists in zip(age_list,plan_list,topic_list):
    response = openai.ChatCompletion.create(
        engine="gpt-4",
        messages = [{"role":"system","content":'Age:'+age_lists+'Plan:'+plan_lists+'Topic:'+topic_lists},
                    {"role":"user","content":QandA_informal_generated}],
        temperature=0.1,
        max_tokens=6500,
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    
    answer = response['choices'][0]['message']['content']
    informal_list.append(answer)
    
    time.sleep(10)
    
    print(answer)
